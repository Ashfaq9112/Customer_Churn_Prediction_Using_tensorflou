# %%
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('customer_churn.csv')
df.head(10)
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService
# 0  7590-VHVEG  Female              0     Yes         No       1           No  \
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
# 5  9305-CDSKC  Female              0      No         No       8          Yes
# 6  1452-KIOVK    Male              0      No        Yes      22          Yes
# 7  6713-OKOMC  Female              0      No         No      10           No
# 8  7892-POOKP  Female              0     Yes         No      28          Yes
# 9  6388-TABGU    Male              0      No        Yes      62          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection
# ...

# %%
df.drop('customerID', axis='columns', inplace=True)

# %%
df.dtypes
# Out:
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
#TotalCharges are in object instead thy should be in float so first we are clearing the empty strings in the and then changing it into numeric

# %%
pd.to_numeric(df.TotalCharges, errors='coerce')
# Out:
# 0         29.85
# 1       1889.50
# 2        108.15
# 3       1840.75
# 4        151.65
#          ...
# 7038    1990.50
# 7039    7362.90
# 7040     346.45
# 7041     306.60
# 7042    6844.50
# Name: TotalCharges, Length: 7043, dtype: float64

# %%
df.shape
# Out:
# (7043, 20)

# %%
len(df[df.TotalCharges == ' '])
# Out:
# 11

# %%
pd.to_numeric(df.TotalCharges, errors='coerce').isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7038    False
# 7039    False
# 7040    False
# 7041    False
# 7042    False
# Name: TotalCharges, Length: 7043, dtype: bool

# %%
df[pd.to_numeric(df.TotalCharges, errors='coerce').isnull()]
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService
# 488   Female              0     Yes        Yes       0           No  \
# 753     Male              0      No        Yes       0          Yes
# 936   Female              0     Yes        Yes       0          Yes
# 1082    Male              0     Yes        Yes       0          Yes
# 1340  Female              0     Yes        Yes       0           No
# 3331    Male              0     Yes        Yes       0          Yes
# 3826    Male              0     Yes        Yes       0          Yes
# 4380  Female              0     Yes        Yes       0          Yes
# 5218    Male              0     Yes        Yes       0          Yes
# 6670  Female              0     Yes        Yes       0          Yes
# 6754    Male              0      No        Yes       0          Yes
#
#          MultipleLines InternetService       OnlineSecurity
# 488   No phone service             DSL                  Yes  \
# ...

# %%
df1 = df[df.TotalCharges!=' '] #changing the df into df where TotalCharges have no ' ' values

# %%
df1
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService
# 0     Female              0     Yes         No       1           No  \
# 1       Male              0      No         No      34          Yes
# 2       Male              0      No         No       2          Yes
# 3       Male              0      No         No      45           No
# 4     Female              0      No         No       2          Yes
# ...      ...            ...     ...        ...     ...          ...
# 7038    Male              0     Yes        Yes      24          Yes
# 7039  Female              0     Yes        Yes      72          Yes
# 7040  Female              0     Yes        Yes      11           No
# 7041    Male              1     Yes         No       4          Yes
# 7042    Male              0      No         No      66          Yes
#
#          MultipleLines InternetService OnlineSecurity OnlineBackup
# 0     No phone service             DSL             No          Yes  \
# ...

# %%
df1.shape
# Out:
# (7032, 20)

# %%
df1.dtypes
# Out:
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
pd.to_numeric(df1.TotalCharges) #changiing to the respective numeric value
# Out:
# 0         29.85
# 1       1889.50
# 2        108.15
# 3       1840.75
# 4        151.65
#          ...
# 7038    1990.50
# 7039    7362.90
# 7040     346.45
# 7041     306.60
# 7042    6844.50
# Name: TotalCharges, Length: 7032, dtype: float64

# %%
df1.TotalCharges = pd.to_numeric(df1.TotalCharges) #stoing the value in df1.totalcharges
# Out:
# C:\Users\firdhous\AppData\Local\Temp\ipykernel_22996\1143557006.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.TotalCharges = pd.to_numeric(df1.TotalCharges) #stoing the value in df1.totalcharges

# %%
df1.TotalCharges.dtype #changed to float
# Out:
# dtype('float64')

# %%
df1.dtypes
# Out:
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges        float64
# Churn                object
# dtype: object

# %%
df1[df1.Churn == 'No']
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService
# 0     Female              0     Yes         No       1           No  \
# 1       Male              0      No         No      34          Yes
# 3       Male              0      No         No      45           No
# 6       Male              0      No        Yes      22          Yes
# 7     Female              0      No         No      10           No
# ...      ...            ...     ...        ...     ...          ...
# 7037  Female              0      No         No      72          Yes
# 7038    Male              0     Yes        Yes      24          Yes
# 7039  Female              0     Yes        Yes      72          Yes
# 7040  Female              0     Yes        Yes      11           No
# 7042    Male              0      No         No      66          Yes
#
#          MultipleLines InternetService       OnlineSecurity
# 0     No phone service             DSL                   No  \
# ...

# %%
len(df1[df1.Churn == "Yes"])
# Out:
# 1869

# %%
tenure_churn_no = df1[df1.Churn=='No'].tenure
tenure_churn_yes = df1[df1.Churn=='Yes'].tenure

# %%
plt.hist([tenure_churn_no,tenure_churn_yes])
plt.xlabel("Tenure")
plt.ylabel("Churn")
# Out:
# Text(0, 0.5, 'Churn')

# %%
tenure_churn_no = df1[df1.Churn=='No'].MonthlyCharges
tenure_churn_yes = df1[df1.Churn=='Yes'].MonthlyCharges

# %%
plt.hist([tenure_churn_no,tenure_churn_yes])
# Out:
# (array([[1452.,  134.,  246.,  485.,  419.,  544.,  597.,  550.,  485.,
#           251.],
#         [ 148.,   57.,  119.,  152.,   53.,  350.,  355.,  319.,  273.,
#            43.]]),
#  array([ 18.25,  28.3 ,  38.35,  48.4 ,  58.45,  68.5 ,  78.55,  88.6 ,
#          98.65, 108.7 , 118.75]),
#  <a list of 2 BarContainer objects>)

# %%
#Now Label encoding

# %%
for c in df1:
    print(df[c].unique())
# Out:
# ['Female' 'Male']
# [0 1]
# ['Yes' 'No']
# ['No' 'Yes']
# [ 1 34  2 45  8 22 10 28 62 13 16 58 49 25 69 52 71 21 12 30 47 72 17 27
#   5 46 11 70 63 43 15 60 18 66  9  3 31 50 64 56  7 42 35 48 29 65 38 68
#  32 55 37 36 41  6  4 33 67 23 57 61 14 20 53 40 59 24 44 19 54 51 26  0
#  39]
# ['No' 'Yes']
# ['No phone service' 'No' 'Yes']
# ['DSL' 'Fiber optic' 'No']
# ['No' 'Yes' 'No internet service']
# ['Yes' 'No' 'No internet service']
# ['No' 'Yes' 'No internet service']
# ['No' 'Yes' 'No internet service']
# ['No' 'Yes' 'No internet service']
# ['No' 'Yes' 'No internet service']
# ['Month-to-month' 'One year' 'Two year']
# ['Yes' 'No']
# ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# [29.85 56.95 53.85 ... 63.1  44.2  78.7 ]
# ['29.85' '1889.5' '108.15' ... '346.45' '306.6' '6844.5']
# ['No' 'Yes']

# %%
def make_unique(df):
    for column in df:
        if df[column].dtype=='object':
            print(f'{column}:{df[column].unique()}')

# %%
df1.replace('No phone service', 'No', inplace=True)
df1.replace('No internet service', 'No', inplace=True)
# Out:
# C:\Users\firdhous\AppData\Local\Temp\ipykernel_22996\2015265041.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.replace('No phone service', 'No', inplace=True)
# C:\Users\firdhous\AppData\Local\Temp\ipykernel_22996\2015265041.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.replace('No internet service', 'No', inplace=True)

# %%
clm = ['Partner','Dependents','PhoneService','MultipleLines','OnlineSecurity','OnlineBackup','DeviceProtection',
      'TechSupport','StreamingTV','StreamingMovies','PaperlessBilling','Churn']
for col in clm:
    df1[col].replace({'Yes':1,'No':0}, inplace=True)
make_unique(df1)
# Out:
# gender:['Female' 'Male']
# InternetService:['DSL' 'Fiber optic' 'No']
# Contract:['Month-to-month' 'One year' 'Two year']
# PaymentMethod:['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# C:\Users\firdhous\AppData\Local\Temp\ipykernel_22996\1961952444.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1[col].replace({'Yes':1,'No':0}, inplace=True)

# %%
df1
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService
# 0     Female              0        1           0       1             0  \
# 1       Male              0        0           0      34             1
# 2       Male              0        0           0       2             1
# 3       Male              0        0           0      45             0
# 4     Female              0        0           0       2             1
# ...      ...            ...      ...         ...     ...           ...
# 7038    Male              0        1           1      24             1
# 7039  Female              0        1           1      72             1
# 7040  Female              0        1           1      11             0
# 7041    Male              1        1           0       4             1
# 7042    Male              0        0           0      66             1
#
#       MultipleLines InternetService  OnlineSecurity  OnlineBackup
# ...

# %%
df1['gender'].replace({'Female':1, 'Male':0}, inplace=True)
# Out:
# C:\Users\firdhous\AppData\Local\Temp\ipykernel_22996\3951318906.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['gender'].replace({'Female':1, 'Male':0}, inplace=True)

# %%
df1
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService
# 0          1              0        1           0       1             0  \
# 1          0              0        0           0      34             1
# 2          0              0        0           0       2             1
# 3          0              0        0           0      45             0
# 4          1              0        0           0       2             1
# ...      ...            ...      ...         ...     ...           ...
# 7038       0              0        1           1      24             1
# 7039       1              0        1           1      72             1
# 7040       1              0        1           1      11             0
# 7041       0              1        1           0       4             1
# 7042       0              0        0           0      66             1
#
#       MultipleLines InternetService  OnlineSecurity  OnlineBackup
# ...

# %%
#One Hot Encoding is the way to express for example in payment method there are three things echeck,mcheck,bt. o if the data is 
#echeck it creates an array with 3 lengths where number one is entered in echeck and the others have 0

# %%
df2 = pd.get_dummies(data=df1, columns=['PaymentMethod','InternetService','Contract'])
df2
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService
# 0          1              0        1           0       1             0  \
# 1          0              0        0           0      34             1
# 2          0              0        0           0       2             1
# 3          0              0        0           0      45             0
# 4          1              0        0           0       2             1
# ...      ...            ...      ...         ...     ...           ...
# 7038       0              0        1           1      24             1
# 7039       1              0        1           1      72             1
# 7040       1              0        1           1      11             0
# 7041       0              1        1           0       4             1
# 7042       0              0        0           0      66             1
#
#       MultipleLines  OnlineSecurity  OnlineBackup  DeviceProtection  ...
# ...

# %%
df2.replace({False:0, True:1}, inplace=True)

# %%
df2
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService
# 0          1              0        1           0       1             0  \
# 1          0              0        0           0      34             1
# 2          0              0        0           0       2             1
# 3          0              0        0           0      45             0
# 4          1              0        0           0       2             1
# ...      ...            ...      ...         ...     ...           ...
# 7038       0              0        1           1      24             1
# 7039       1              0        1           1      72             1
# 7040       1              0        1           1      11             0
# 7041       0              1        1           0       4             1
# 7042       0              0        0           0      66             1
#
#       MultipleLines  OnlineSecurity  OnlineBackup  DeviceProtection  ...
# ...

# %%
df2.dtypes

# %%
#Now Scaling... we will minmax scaling Monthly charges, Total charges and tenure have to be scaled

# %%
scaling = ['tenure','MonthlyCharges','TotalCharges']

# %%
# !pip install sklearn

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# %%
df2[scaling] = scaler.fit_transform(df2[scaling])

# %%
df2.tail()
# Out:
#       gender  SeniorCitizen  Partner  Dependents    tenure  PhoneService
# 7038       0              0        1           1  0.323944             1  \
# 7039       1              0        1           1  1.000000             1
# 7040       1              0        1           1  0.140845             0
# 7041       0              1        1           0  0.042254             1
# 7042       0              0        0           0  0.915493             1
#
#       MultipleLines  OnlineSecurity  OnlineBackup  DeviceProtection  ...
# 7038              1               1             0                 1  ...  \
# 7039              1               0             1                 1  ...
# 7040              0               1             0                 0  ...
# 7041              1               0             0                 0  ...
# 7042              0               1             0                 1  ...
#
#       PaymentMethod_Bank transfer (automatic)
# ...

# %% [markdown]
# ##

# %%
df2[0:15]
# Out:
#     gender  SeniorCitizen  Partner  Dependents    tenure  PhoneService
# 0        1              0        1           0  0.000000             0  \
# 1        0              0        0           0  0.464789             1
# 2        0              0        0           0  0.014085             1
# 3        0              0        0           0  0.619718             0
# 4        1              0        0           0  0.014085             1
# 5        1              0        0           0  0.098592             1
# 6        0              0        0           1  0.295775             1
# 7        1              0        0           0  0.126761             0
# 8        1              0        1           0  0.380282             1
# 9        0              0        0           1  0.859155             1
# 10       0              0        1           1  0.169014             1
# 11       0              0        0           0  0.211268             1
# ...

# %%
column = ['TotalCharges','MonthlyCharges']

# %%
df2.loc[1:10:1,'gender':'Churn' ]
# Out:
#     gender  SeniorCitizen  Partner  Dependents    tenure  PhoneService
# 1        0              0        0           0  0.464789             1  \
# 2        0              0        0           0  0.014085             1
# 3        0              0        0           0  0.619718             0
# 4        1              0        0           0  0.014085             1
# 5        1              0        0           0  0.098592             1
# 6        0              0        0           1  0.295775             1
# 7        1              0        0           0  0.126761             0
# 8        1              0        1           0  0.380282             1
# 9        0              0        0           1  0.859155             1
# 10       0              0        1           1  0.169014             1
#
#     MultipleLines  OnlineSecurity  OnlineBackup  DeviceProtection
# 1               0               1             0                 1  \
# ...

# %%
#Now test and training the model

# %%
from sklearn.model_selection import train_test_split

# %%
x = df2.drop('Churn', axis='columns')
y = df2['Churn']

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
len(x_train.columns
)
# Out:
# 26

# %%
import tensorflow as tf
from tensorflow import keras


model = keras.Sequential([
    keras.layers.Dense(25, input_shape=(26,), activation='relu'),#input layer
    keras.layers.Dense(20,activation='relu'),#hidden layer
    keras.layers.Dense(1,activation='sigmoid')#output layer for getting output
])

model.compile(optimizer='adam',
             loss='binary_crossentropy',
             metrics=['accuracy'])

model.fit(x_train,y_train, epochs=50)
# Out:
# Epoch 1/50
# 176/176 [==============================] - 1s 2ms/step - loss: 0.5297 - accuracy: 0.7172
# Epoch 2/50
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4310 - accuracy: 0.7902
# Epoch 3/50
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4215 - accuracy: 0.7977
# Epoch 4/50
# 176/176 [==============================] - 1s 4ms/step - loss: 0.4173 - accuracy: 0.8018
# Epoch 5/50
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4165 - accuracy: 0.8037
# Epoch 6/50
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4125 - accuracy: 0.8071
# Epoch 7/50
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4111 - accuracy: 0.8105
# Epoch 8/50
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4107 - accuracy: 0.8075
# Epoch 9/50
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4085 - accuracy: 0.8098
# Epoch 10/50
# ...
